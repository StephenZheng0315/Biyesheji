# %%
from netCDF4 import Dataset

# %%
file_name = r'./data/MERRA2_300.tavgU_2d_adg_Nx.200601.hdf'
# Out:
#   File "<ipython-input-2-20f397cef9df>", line 1
#     file_path =
#                 ^
# SyntaxError: invalid syntax

# %%
with nc.Dataset(filename) as file:
    file.set_auto_mask(False)  # 可选
    variables = {x: file[x][()] for x in file.variables}

# %%
import tensorflow as tf

# %%
import sys

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# %%
# setup Lambert Conformal basemap.
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution='c',lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='aqua')
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')
# draw parallels and meridians.
# label parallels on right and top
# meridians on bottom and left
parallels = np.arange(0.,81,10.)
# labels = [left,right,top,bottom]
m.drawparallels(parallels,labels=[False,True,True,False])
meridians = np.arange(10.,351.,20.)
m.drawmeridians(meridians,labels=[True,False,False,True])
# plot blue dot on Boulder, colorado and label it as such.
lon, lat = -104.237, 40.125 # Location of Boulder
# convert to map projection coords.
# Note that lon,lat can be scalars, lists or numpy arrays.
xpt,ypt = m(lon,lat)
# convert back to lat/lon
lonpt, latpt = m(xpt,ypt,inverse=True)
m.plot(xpt,ypt,'bo')  # plot a blue dot there
# put some text next to the dot, offset a little bit
# (the offset is in map projection coordinates)
plt.text(xpt+100000,ypt+100000,'Boulder (%5.1fW,%3.1fN)' % (lonpt,latpt))
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-bdbfbf43cd1f> in <module>
#       5 # convert back to lat/lon
#       6 lonpt, latpt = m(xpt,ypt,inverse=True)
# ----> 7 m.plot(xpt,ypt,'bo')  # plot a blue dot there
#       8 # put some text next to the dot, offset a little bit
#       9 # (the offset is in map projection coordinates)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\mpl_toolkits\basemap\__init__.py in with_transform(self, x, y, *args, **kwargs)
#     558             # convert lat/lon coords to map projection coords.
#     559             x, y = self(x,y)
# --> 560         return plotfunc(self,x,y,*args,**kwargs)
#     561     return with_transform
#     562
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\mpl_toolkits\basemap\__init__.py in plot(self, *args, **kwargs)
#    3288         self.set_axes_limits(ax=ax)
#    3289         # clip to map limbs
# -> 3290         ret,c = self._cliplimb(ax,ret)
#    3291         return ret
#    3292
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\mpl_toolkits\basemap\__init__.py in _cliplimb(self, ax, coll)
#    1814         c = self._mapboundarydrawn
#    1815         if c not in ax.patches:
# -> 1816             p = ax.add_patch(c)
#    1817             #p.set_clip_on(False)
#    1818         try:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    2028         Add a `~.Patch` to the axes' patches; return the patch.
#    2029         """
# -> 2030         self._set_artist_props(p)
#    2031         if p.get_clip_path() is None:
#    2032             p.set_clip_path(self.patch)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_base.py in _set_artist_props(self, a)
#     955     def _set_artist_props(self, a):
#     956         """Set the boilerplate props for artists added to axes."""
# --> 957         a.set_figure(self.figure)
#     958         if not a.is_transform_set():
#     959             a.set_transform(self.transData)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py in set_figure(self, fig)
#     702         # to more than one Axes
#     703         if self.figure is not None:
# --> 704             raise RuntimeError("Can not put single artist in "
#     705                                "more than one figure")
#     706         self.figure = fig
#
# RuntimeError: Can not put single artist in more than one figure
